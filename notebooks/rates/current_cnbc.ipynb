# %%
import requests
import time
import nest_asyncio
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.express as px
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from  matplotlib.colors import LinearSegmentedColormap
from datetime import datetime, date, timedelta
from typing import Dict, Callable, List
from IPython.display import clear_output, display
from pandas.tseries.offsets import BDay, BMonthBegin
from pandas.io.formats.style import Styler

# %%
def plot_current_yields(current_yields_dict: Dict[str, str | int]):
    maturities = list(current_yields_dict.keys())
    fig = go.Figure()
    fig.add_trace(
        go.Scatter(
            x=[1, 2, 3, 5, 7, 10, 20, 30],
            y=[
                float(str(x["last"]).strip("%")) / 100
                for x in current_yields_dict.values()
            ],
            mode="lines+markers",
            name="Yield",
        )
    )

    timestamps = [current_yields_dict[mat]["timedate"] for mat in maturities]
    timestamp = max(
        datetime.strptime(time.split(" ")[0] + " " + time.split(" ")[1], "%I:%M %p")
        for time in timestamps
    ).strftime("%I:%M %p %Z")

    fig.update_layout(
        title=f"Current Yield Curve as of {timestamp}",
        xaxis_title="Maturity (Months)",
        yaxis_title="Yield (%)",
        xaxis=dict(tickvals=[1, 2, 3, 5, 7, 10, 20, 30], ticktext=maturities),
        showlegend=False,
    )

    fig.show()


def get_business_days():
    today = pd.Timestamp.now().normalize()
    last_business_day = today - BDay(1)
    a_week_ago = today - pd.DateOffset(weeks=1)
    business_day_week_ago = pd.bdate_range(end=a_week_ago, periods=1)[0]
    a_month_ago = today - pd.DateOffset(months=1)
    business_day_month_ago = pd.bdate_range(end=a_month_ago, periods=1)[0]
    a_year_ago = today - pd.DateOffset(years=1)
    business_day_year_ago = pd.bdate_range(end=a_year_ago, periods=1)[0]

    return (
        last_business_day,
        business_day_week_ago,
        business_day_month_ago,
        business_day_year_ago,
    )


def parse_to_float(value):
    if str(value).endswith("%"):
        return float(value.strip("%")) / 100
    else:
        return float(value)


def plot_current_yields_and_historicals(
    current_yields_dict: Dict[str, str | int],
    df_historical_par_yields: pd.DataFrame,
    df_recent_spots: pd.DataFrame = None,
    plot_yesterday=False,
    plot_week=False,
    plot_month=False,
    plot_year=False,
    plot_five_min=False,
    plot_ten_min=False,
    plot_fifteen_min=False,
    plot_thirty_min=False,
    plot_sixty_min=False,
    plot_ninety_min=False,
    plot_120_min=False,
    custom_date: List[date] = None,
):
    adjusted_months = [1, 2, 3, 5, 7, 10, 20, 30]
    maturities = list(current_yields_dict.keys())
    fig = go.Figure()
    fig.add_trace(
        go.Scatter(
            x=adjusted_months,
            y=[
                float(str(x["last"]).strip("%")) / 100
                for x in current_yields_dict.values()
            ],
            mode="lines+markers",
            name="Current",
        )
    )

    yesterday, week, month, year = get_business_days()

    def plot_historicals(date):
        formatted_date = date.strftime("%Y-%m-%d")
        yields = df_historical_par_yields.loc[
            df_historical_par_yields["Date"] == formatted_date
        ]
        yields = yields.values.tolist()[0]
        del yields[:6]
        yields = [y / 100 for y in yields]
        fig.add_trace(
            go.Scatter(
                x=adjusted_months,
                y=yields,
                mode="lines+markers",
                name=f"{formatted_date}",
            )
        )

    def plot_recent_spots(min_key: str):
        yields = df_recent_spots.loc[df_recent_spots["Date"] == min_key]
        yields = yields.values.tolist()[0]
        del yields[:1]
        yields = [parse_to_float(y) / 100 for y in yields]
        fig.add_trace(
            go.Scatter(
                x=adjusted_months,
                y=yields,
                mode="lines+markers",
                name=f"{min_key}",
            )
        )

    if plot_yesterday:
        plot_historicals(yesterday)
    if plot_week:
        plot_historicals(week)
    if plot_month:
        plot_historicals(month)
    if plot_year:
        plot_historicals(year)
    if custom_date:
        [plot_historicals(date) for date in custom_date]

    if plot_five_min:
        plot_recent_spots("5.0m"),
    if plot_ten_min:
        plot_recent_spots("10.0m"),
    if plot_fifteen_min:
        plot_recent_spots("15.0m"),
    if plot_thirty_min:
        plot_recent_spots("30.0m"),
    if plot_sixty_min:
        plot_recent_spots("60.0m"),
    if plot_ninety_min:
        plot_recent_spots("90.0m")
    if plot_120_min:
        plot_recent_spots("120.0m")

    [plot_recent_spots(min_key) for min_key in custom_date] if custom_date else None

    timestamps = [current_yields_dict[mat]["timedate"] for mat in maturities]
    timestamp = max(
        datetime.strptime(time.split(" ")[0] + " " + time.split(" ")[1], "%I:%M %p")
        for time in timestamps
    ).strftime("%I:%M %p %Z")

    fig.update_layout(
        title=f"Current Yield Curve as of {timestamp}",
        xaxis_title="Maturity (Months)",
        yaxis_title="Yield (%)",
        xaxis=dict(tickvals=[1, 2, 3, 5, 7, 10, 20, 30], ticktext=maturities),
        showlegend=True,
    )

    fig.show()

# %%
def yields_corr(
    current_yields_dict: Dict[str, str | int],
    df_historical_par_yields: pd.DataFrame = None,
    df_recent_spots: pd.DataFrame = None,
    show_recents_days=False,
    show_recent_spots_mins=False,
    num_of_months: int = None,
):
    def find_historical_yields(date):
        try:
            formatted_date = date.strftime("%Y-%m-%d")
            yields = df_historical_par_yields.loc[
                df_historical_par_yields["Date"] == formatted_date
            ]
            yields = yields.values.tolist()[0]
            del yields[:6]
            yields = [y / 100 for y in yields]
            return {date: yields}
        except Exception as e:
            print(f"Date: {date} probably not found: ", e, " trying next day")
            next_day = date + timedelta(days=1)
            return find_historical_yields(next_day)


    maturities = list(current_yields_dict.keys())
    timestamps = [current_yields_dict[mat]["timedate"] for mat in maturities]
    timestamp = max(
        datetime.strptime(time.split(" ")[0] + " " + time.split(" ")[1], "%I:%M %p")
        for time in timestamps
    ).strftime("%H:%M:%S")
    today = datetime.now().strftime("%Y-%m-%d")
    formatted_current_datetime = f"{today} {timestamp}"
    current_datetime_obj = datetime.strptime(
        formatted_current_datetime, "%Y-%m-%d %H:%M:%S"
    )

    current_yields = {
        current_datetime_obj: [
            float(str(x["last"]).strip("%")) / 100 for x in current_yields_dict.values()
        ]
    }
    
    current_date = pd.Timestamp.now().normalize()
    months = [current_date - BMonthBegin(i) for i in range(2, num_of_months or 13)]
    monthly_historic_yields = [find_historical_yields(m) for m in months] if df_historical_par_yields is not None else []
    
    all_yields = [current_yields]
    
    if show_recent_spots_mins and df_recent_spots is not None:
        min_keys = df_recent_spots["Date"].values.tolist()
        for min_key in min_keys:
            yields = df_recent_spots.loc[
                df_recent_spots["Date"] == min_keys
            ]
            yields = yields.values.tolist()[0]
            del yields[:1]
            yields = [parse_to_float(y) / 100 for y in yields]
            all_yields.append({min_key: yields})

    if show_recents_days:
        yesterday, week, month, _ = get_business_days()
        yesterday_yields = find_historical_yields(yesterday)
        last_week_yields = find_historical_yields(week)
        last_month_yields = find_historical_yields(month)

        all_yields += [
            yesterday_yields,
            last_week_yields,
            last_month_yields,
        ] + monthly_historic_yields
    else:
        all_yields += monthly_historic_yields 

    cols = ["US1Y", "US2Y", "US3Y", "US5Y", "US7Y", "US10Y", "US20Y", "US30Y"]
    df_historical_monthly_yields = pd.DataFrame.from_dict(
        {list(d.keys())[0]: list(d.values())[0] for d in all_yields},
        orient="index",
        columns=cols,
    )
    df_historical_monthly_yields.index.name = "Date"
    df_historical_monthly_yields = df_historical_monthly_yields.reset_index()
    df_historical_monthly_yields_corr = pd.DataFrame(
        [
            (key, value)
            for item in all_yields
            for key, value in item.items()
        ],
        columns=["Date", "Values"],
    )
    df_historical_monthly_yields_corr.set_index("Date", inplace=True)

    def categorize_correlation(r):
        if r >= 0.7:
            return "Normal"
        elif 0.7 > r >= 0.35:
            return "Slight Normal"
        elif 0.35 > r > -0.35:
            return "Flat"
        elif -0.35 >= r > -0.7:
            return "Slight Inverted"
        elif r <= -0.7:
            return "Inverted"
        else:
            return "Unknown"

    # Pearson's correlation coefficient for each set of values
    correlations = []
    for values in df_historical_monthly_yields_corr["Values"]:
        if all(v is not None for v in values):
            index = np.arange(len(values))
            correlation = np.corrcoef(index, values)[0, 1]
        else:
            correlation = np.nan
        correlations.append(correlation)

    df_historical_monthly_yields_corr["Correlation"] = correlations
    df_historical_monthly_yields_corr["Category"] = df_historical_monthly_yields_corr[
        "Correlation"
    ].apply(categorize_correlation)
    df_historical_monthly_yields_corr[["Correlation", "Category"]]
    df_historical_monthly_yields = pd.merge(
        df_historical_monthly_yields, df_historical_monthly_yields_corr, on="Date"
    )
    df_historical_monthly_yields = df_historical_monthly_yields.drop("Values", axis=1)

    return df_historical_monthly_yields

# %%
def calc_daily_spreads(
    current_yields_dict: Dict[str, Dict[str, str]],
    mat1: str,
    mat2: str,
    print_out=False,
) -> Dict[str, int]:
    def s_to_f(s):
        return float(str(s).strip("%")) * 10

    spreads = {
        "spread_title": f"{mat1} - {mat2} (basis points)",
        "last_spread": round(
            (
                s_to_f(current_yields_dict[mat1]["last"])
                - s_to_f(current_yields_dict[mat2]["last"])
            )
            * 10,
            2,
        ),
        "open_spread": round(
            (
                s_to_f(current_yields_dict[mat1]["open"])
                - s_to_f(current_yields_dict[mat2]["open"])
            )
            * 10,
            2,
        ),
        "high_spread": round(
            (
                s_to_f(current_yields_dict[mat1]["high"])
                - s_to_f(current_yields_dict[mat2]["high"])
            )
            * 10,
            2,
        ),
        "low_spread": round(
            (
                s_to_f(current_yields_dict[mat1]["low"])
                - s_to_f(current_yields_dict[mat2]["low"])
            )
            * 10,
            2,
        ),
    }

    if print_out:
        print("timedate: ", current_yields_dict[mat1]["timedate"])
        print("name: ", f"{mat1} - {mat2} (basis points)")
        print("last: ", spreads["last_spread"])
        print("open: ", spreads["open_spread"])
        print("high: ", spreads["high_spread"])
        print("low: ", spreads["low_spread"])
        print(f"{mat1} del: ", current_yields_dict[mat1]["change"])
        print(f"{mat2} del: ", current_yields_dict[mat2]["change"])
        print("----------------")

    return spreads

# %%
def get_current_yield(mat, print_out=False) -> Dict[str, str | int]:
    res = requests.get(
        f"https://quote.cnbc.com/quote-html-webservice/restQuote/symbolType/symbol?symbols={mat}&requestMethod=itv&noform=1&partnerId=2&fund=1&exthrs=1&output=json&events=1"
    )
    if res.status_code != 200:
        return f"Bad Status: {res.status_code}"
    
    us_current_yield = res.json()["FormattedQuoteResult"]["FormattedQuote"][0]

    if print_out:
        print("timedate: ", us_current_yield["last_timedate"])
        print("name: ", us_current_yield["name"])
        print("last: ", us_current_yield["last"])
        print("open: ", us_current_yield["open"])
        print("high: ", us_current_yield["high"])
        print("low: ", us_current_yield["low"])
        print("change: ", us_current_yield["change"])
        print("----------------")

    return {
        "timedate": us_current_yield["last_timedate"],
        "name": us_current_yield["name"],
        "last": us_current_yield["last"],
        "open": us_current_yield["open"],
        "high": us_current_yield["high"],
        "low": us_current_yield["low"],
        "change": us_current_yield["change"],
    }

# %%
def yields_candlestick_plot(
    data: List[Dict[str, str]],
    use_candlestick=False,
    use_today=False,
    mat_label=None,
    just_close_plot=False,
):
    opens = [float(str((item["open"])).strip("%")) for item in data]
    highs = [float(str((item["high"])).strip("%")) for item in data]
    lows = [float(str((item["low"])).strip("%")) for item in data]
    closes = [float(str((item["close"])).strip("%")) for item in data]
    if use_today:
        trade_times = [
            datetime.fromtimestamp(int(item["tradeTimeinMills"]) / 1000).strftime(
                "%Y-%m-%d %H:%M:%S"
            )
            for item in data
            if datetime.fromtimestamp(int(item["tradeTimeinMills"]) / 1000)
            >= datetime.today().replace(hour=0, minute=0, second=0, microsecond=0)
        ]
    else:
        trade_times = [
            datetime.fromtimestamp(int(item["tradeTimeinMills"]) / 1000).strftime(
                "%Y-%m-%d %H:%M:%S"
            )
            for item in data
        ]

    if use_candlestick:
        fig = go.Figure(
            data=[
                go.Candlestick(
                    x=trade_times, open=opens, high=highs, low=lows, close=closes
                )
            ]
        )
    else:
        fig = go.Figure()
        if just_close_plot:
            fig.add_trace(
                go.Scatter(x=trade_times, y=closes, mode="lines", name="Close")
            )
        else:
            fig.add_trace(go.Scatter(x=trade_times, y=opens, mode="lines", name="Open"))
            fig.add_trace(go.Scatter(x=trade_times, y=highs, mode="lines", name="High"))
            fig.add_trace(go.Scatter(x=trade_times, y=lows, mode="lines", name="Low"))
            fig.add_trace(
                go.Scatter(x=trade_times, y=closes, mode="lines", name="Close")
            )

    fig.update_layout(
        title="Treasury Yield Data"
        if not mat_label
        else f"{mat_label} as of {datetime.now()}",
        xaxis_title="Trade Time",
        yaxis_title="Yield",
        xaxis_rangeslider_visible=False,
    )

    fig.show()

# %%
def periodic_work(interval: int, function: Callable):
    while True:
        function()
        time.sleep(interval)
        clear_output(wait=True)

# %%
def color_red(val):
    if isinstance(val, (int, float, complex)) and not isinstance(val, bool):
        color = "red" if val > 0 else "green"
    else:
        color = "none"

    return f"background-color: {color}"


def wrapper():
    current_yields_dict = {
        mat: get_current_yield(mat)
        for mat in ["US1Y", "US2Y", "US3Y", "US5Y", "US7Y", "US10Y", "US20Y", "US30Y"]
    }
    df = pd.DataFrame(current_yields_dict)
    df.drop(df.index[[1]], inplace=True)
    df.iloc[5] = pd.to_numeric(df.iloc[5], errors="coerce")
    df.iloc[5] = df.iloc[5] * 100

    styled_df = df.style.applymap(color_red)
    display(styled_df)
    return styled_df


# periodic_work(5, wrapper)

# %%
# ! python C:/Users/chris/trade/curr_pos/common/treasuries.py

df_historical_par_yields_2023 = pd.read_excel(r'C:\Users\chris\trade\curr_pos\treasuries\2023_daily_treasury_rates.xlsx', parse_dates=['Date'])
df_historical_par_yields_2022 = pd.read_excel(r'C:\Users\chris\trade\curr_pos\treasuries\2022_daily_treasury_rates.xlsx', parse_dates=['Date'])
df_historical_par_yields_2021 = pd.read_excel(r'C:\Users\chris\trade\curr_pos\treasuries\2021_daily_treasury_rates.xlsx', parse_dates=['Date'])
df_historical_par_yields_2020 = pd.read_excel(r'C:\Users\chris\trade\curr_pos\treasuries\2020_daily_treasury_rates.xlsx', parse_dates=['Date'])
df_historical_par_yields_2019 = pd.read_excel(r'C:\Users\chris\trade\curr_pos\treasuries\2019_daily_treasury_rates.xlsx', parse_dates=['Date'])
df_historical_par_yields = pd.concat([df_historical_par_yields_2023, df_historical_par_yields_2022, df_historical_par_yields_2022, df_historical_par_yields_2021, df_historical_par_yields_2020, df_historical_par_yields_2019])

df_historical_par_yields
# Out:
#           Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0   2023-12-07  5.53  5.54  5.44  5.47  5.36  5.05  4.58  4.31  4.11  4.16
# 1   2023-12-06  5.54  5.50  5.45  5.47  5.38  5.07  4.60  4.33  4.12  4.16
# 2   2023-12-05  5.54  5.51  5.45  5.46  5.37  5.06  4.57  4.33  4.14  4.20
# 3   2023-12-04  5.55  5.53  5.46  5.47  5.41  5.10  4.64  4.40  4.23  4.30
# 4   2023-12-01  5.55  5.53  5.43  5.45  5.33  5.05  4.56  4.31  4.14  4.22
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 245 2019-01-08  2.40  2.42  2.46   NaN  2.54  2.60  2.58  2.57  2.58  2.63
# 246 2019-01-07  2.42  2.42  2.45   NaN  2.54  2.58  2.53  2.51  2.53  2.60
# 247 2019-01-04  2.40  2.42  2.42   NaN  2.51  2.57  2.50  2.47  2.49  2.56
# 248 2019-01-03  2.42  2.42  2.41   NaN  2.47  2.50  2.39  2.35  2.37  2.44
# 249 2019-01-02  2.40  2.40  2.42   NaN  2.51  2.60  2.50  2.47  2.49  2.56
#
#      10 Yr  20 Yr  30 Yr
# 0     4.14   4.42   4.25
# 1     4.12   4.40   4.22
# 2     4.18   4.48   4.30
# 3     4.28   4.61   4.43
# 4     4.22   4.58   4.40
# ..     ...    ...    ...
# 245   2.73   2.88   3.00
# 246   2.70   2.86   2.99
# 247   2.67   2.83   2.98
# 248   2.56   2.75   2.92
# 249   2.66   2.83   2.97
#
# [1485 rows x 14 columns]

# %%
mats = ["US1Y", "US2Y", "US3Y", "US5Y", "US7Y", "US10Y", "US20Y", "US30Y"]
current_yields_dict = {mat: get_current_yield(mat) for mat in mats}
df = pd.DataFrame(current_yields_dict)
df.drop(df.index[[1]], inplace=True)
df.iloc[5] = pd.to_numeric(df.iloc[5], errors='coerce')
df.iloc[5] = df.iloc[5] * 100
styled_df = df.style.applymap(color_red)
styled_df
# Out:
# <style type="text/css">
# #T_0e207_row0_col0, #T_0e207_row0_col1, #T_0e207_row0_col2, #T_0e207_row0_col3, #T_0e207_row0_col4, #T_0e207_row0_col5, #T_0e207_row0_col6, #T_0e207_row0_col7, #T_0e207_row1_col0, #T_0e207_row1_col1, #T_0e207_row1_col2, #T_0e207_row1_col3, #T_0e207_row1_col4, #T_0e207_row1_col5, #T_0e207_row1_col6, #T_0e207_row1_col7, #T_0e207_row2_col0, #T_0e207_row2_col1, #T_0e207_row2_col2, #T_0e207_row2_col3, #T_0e207_row2_col4, #T_0e207_row2_col5, #T_0e207_row2_col6, #T_0e207_row2_col7, #T_0e207_row3_col0, #T_0e207_row3_col1, #T_0e207_row3_col2, #T_0e207_row3_col3, #T_0e207_row3_col4, #T_0e207_row3_col5, #T_0e207_row3_col6, #T_0e207_row3_col7, #T_0e207_row4_col0, #T_0e207_row4_col1, #T_0e207_row4_col2, #T_0e207_row4_col3, #T_0e207_row4_col4, #T_0e207_row4_col5, #T_0e207_row4_col6, #T_0e207_row4_col7 {
#   background-color: none;
# }
# #T_0e207_row5_col0, #T_0e207_row5_col1, #T_0e207_row5_col2, #T_0e207_row5_col3, #T_0e207_row5_col4, #T_0e207_row5_col5, #T_0e207_row5_col6, #T_0e207_row5_col7 {
#   background-color: red;
# }
# </style>
# <table id="T_0e207">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e207_level0_col0" class="col_heading level0 col0" >US1Y</th>
#       <th id="T_0e207_level0_col1" class="col_heading level0 col1" >US2Y</th>
#       <th id="T_0e207_level0_col2" class="col_heading level0 col2" >US3Y</th>
#       <th id="T_0e207_level0_col3" class="col_heading level0 col3" >US5Y</th>
#       <th id="T_0e207_level0_col4" class="col_heading level0 col4" >US7Y</th>
#       <th id="T_0e207_level0_col5" class="col_heading level0 col5" >US10Y</th>
#       <th id="T_0e207_level0_col6" class="col_heading level0 col6" >US20Y</th>
#       <th id="T_0e207_level0_col7" class="col_heading level0 col7" >US30Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e207_level0_row0" class="row_heading level0 row0" >timedate</th>
#       <td id="T_0e207_row0_col0" class="data row0 col0" >5:05 PM EST</td>
#       <td id="T_0e207_row0_col1" class="data row0 col1" >5:05 PM EST</td>
#       <td id="T_0e207_row0_col2" class="data row0 col2" >5:05 PM EST</td>
#       <td id="T_0e207_row0_col3" class="data row0 col3" >5:05 PM EST</td>
#       <td id="T_0e207_row0_col4" class="data row0 col4" >5:05 PM EST</td>
#       <td id="T_0e207_row0_col5" class="data row0 col5" >5:05 PM EST</td>
#       <td id="T_0e207_row0_col6" class="data row0 col6" >5:05 PM EST</td>
#       <td id="T_0e207_row0_col7" class="data row0 col7" >5:05 PM EST</td>
#     </tr>
#     <tr>
#       <th id="T_0e207_level0_row1" class="row_heading level0 row1" >last</th>
#       <td id="T_0e207_row1_col0" class="data row1 col0" >5.139%</td>
#       <td id="T_0e207_row1_col1" class="data row1 col1" >4.723%</td>
#       <td id="T_0e207_row1_col2" class="data row1 col2" >4.46%</td>
#       <td id="T_0e207_row1_col3" class="data row1 col3" >4.243%</td>
#       <td id="T_0e207_row1_col4" class="data row1 col4" >4.271%</td>
#       <td id="T_0e207_row1_col5" class="data row1 col5" >4.229%</td>
#       <td id="T_0e207_row1_col6" class="data row1 col6" >4.489%</td>
#       <td id="T_0e207_row1_col7" class="data row1 col7" >4.308%</td>
#     </tr>
#     <tr>
#       <th id="T_0e207_level0_row2" class="row_heading level0 row2" >open</th>
#       <td id="T_0e207_row2_col0" class="data row2 col0" >5.076%</td>
#       <td id="T_0e207_row2_col1" class="data row2 col1" >4.593%</td>
#       <td id="T_0e207_row2_col2" class="data row2 col2" >4.34%</td>
#       <td id="T_0e207_row2_col3" class="data row2 col3" >4.133%</td>
#       <td id="T_0e207_row2_col4" class="data row2 col4" >4.179%</td>
#       <td id="T_0e207_row2_col5" class="data row2 col5" >4.153%</td>
#       <td id="T_0e207_row2_col6" class="data row2 col6" >4.435%</td>
#       <td id="T_0e207_row2_col7" class="data row2 col7" >4.26%</td>
#     </tr>
#     <tr>
#       <th id="T_0e207_level0_row3" class="row_heading level0 row3" >high</th>
#       <td id="T_0e207_row3_col0" class="data row3 col0" >5.156%</td>
#       <td id="T_0e207_row3_col1" class="data row3 col1" >4.74%</td>
#       <td id="T_0e207_row3_col2" class="data row3 col2" >4.486%</td>
#       <td id="T_0e207_row3_col3" class="data row3 col3" >4.287%</td>
#       <td id="T_0e207_row3_col4" class="data row3 col4" >4.326%</td>
#       <td id="T_0e207_row3_col5" class="data row3 col5" >4.278%</td>
#       <td id="T_0e207_row3_col6" class="data row3 col6" >4.548%</td>
#       <td id="T_0e207_row3_col7" class="data row3 col7" >4.36%</td>
#     </tr>
#     <tr>
#       <th id="T_0e207_level0_row4" class="row_heading level0 row4" >low</th>
#       <td id="T_0e207_row4_col0" class="data row4 col0" >5.068%</td>
#       <td id="T_0e207_row4_col1" class="data row4 col1" >4.593%</td>
#       <td id="T_0e207_row4_col2" class="data row4 col2" >4.34%</td>
#       <td id="T_0e207_row4_col3" class="data row4 col3" >4.133%</td>
#       <td id="T_0e207_row4_col4" class="data row4 col4" >4.177%</td>
#       <td id="T_0e207_row4_col5" class="data row4 col5" >4.147%</td>
#       <td id="T_0e207_row4_col6" class="data row4 col6" >4.427%</td>
#       <td id="T_0e207_row4_col7" class="data row4 col7" >4.251%</td>
#     </tr>
#     <tr>
#       <th id="T_0e207_level0_row5" class="row_heading level0 row5" >change</th>
#       <td id="T_0e207_row5_col0" class="data row5 col0" >8.300000</td>
#       <td id="T_0e207_row5_col1" class="data row5 col1" >14.300000</td>
#       <td id="T_0e207_row5_col2" class="data row5 col2" >13.900000</td>
#       <td id="T_0e207_row5_col3" class="data row5 col3" >13.100000</td>
#       <td id="T_0e207_row5_col4" class="data row5 col4" >11.500000</td>
#       <td id="T_0e207_row5_col5" class="data row5 col5" >10.000000</td>
#       <td id="T_0e207_row5_col6" class="data row5 col6" >7.000000</td>
#       <td id="T_0e207_row5_col7" class="data row5 col7" >6.200000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# args = " ".join(str(x) for x in [69, 420])
# %run C:/Users/chris/trade/curr_pos/common/cnbc.py $args
! python C:/Users/chris/trade/curr_pos/common/cnbc.py 0 1 5 10 15 20 25 30 45 60 75 90 105 120 135 150 165 180 195 210 225 240 255 270 285 300 315 330 360 420 480 540 600

xlsx = pd.ExcelFile(r"C:\Users\chris\trade\curr_pos\rates\recent_spots.xlsx")
recent_spots_df_dict: Dict[str, pd.DataFrame] = {sheet_name: pd.read_excel(xlsx, sheet_name) for sheet_name in xlsx.sheet_names}

mats = ["Date", "US1Y", "US2Y", "US3Y", "US5Y", "US7Y", "US10Y", "US20Y", "US30Y"]
df_recent_spots = pd.DataFrame(columns=mats)
for mat, df in recent_spots_df_dict.items():
    row = [mat] + df["close"].values.tolist()
    df_recent_spots = pd.concat([pd.DataFrame([row], columns=df_recent_spots.columns), df_recent_spots], ignore_index=True)
    
# df_recent_spots = df_recent_spots.sort_values(by='Date', key=lambda x: print(x))
df_recent_spots["Date"] = df_recent_spots["Date"].str.replace('m', '').astype(float)
df_recent_spots = df_recent_spots.sort_values(by="Date", ascending=True)
df_recent_spots["Date"] = df_recent_spots["Date"].apply(lambda x: f"{str(x)}m")

styled_recent_spot_df = df_recent_spots.style.background_gradient(
    cmap=LinearSegmentedColormap.from_list("gr", ["g", "w", "r"], N=128),
    subset=[col for col in df_recent_spots.columns if col not in ["Date"]],
)
styled_recent_spot_df
# Out:
# {'US1Y': {'maturity': 'US1Y', '0.0m': {'open': '5.076%', 'high': '5.156%', 'low': '5.068%', 'close': 5.13, 'volume': None, 'tradeTime': '20231208170500', 'tradeTimeinMills': '1702073100000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 22, 5), 'mat': 'US1Y'}, '1.0m': {'open': '5.076%', 'high': '5.156%', 'low': '5.068%', 'close': 5.13, 'volume': None, 'tradeTime': '20231208170500', 'tradeTimeinMills': '1702073100000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 22, 5), 'mat': 'US1Y'}, '5.0m': {'open': '5.1360', 'high': '5.1360', 'low': '5.1360', 'close': '5.1360', 'volume': None, 'tradeTime': '20231208170000', 'tradeTimeinMills': '1702072800000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 22, 0), 'mat': 'US1Y'}, '10.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208165700', 'tradeTimeinMills': '1702072620000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 57), 'mat': 'US1Y'}, '15.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208165700', 'tradeTimeinMills': '1702072620000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 57), 'mat': 'US1Y'}, '20.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208164200', 'tradeTimeinMills': '1702071720000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 42), 'mat': 'US1Y'}, '25.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208164200', 'tradeTimeinMills': '1702071720000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 42), 'mat': 'US1Y'}, '30.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208164200', 'tradeTimeinMills': '1702071720000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 42), 'mat': 'US1Y'}, '45.0m': {'open': '5.1360', 'high': '5.1420', 'low': '5.1360', 'close': '5.1420', 'volume': None, 'tradeTime': '20231208161800', 'tradeTimeinMills': '1702070280000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 18), 'mat': 'US1Y'}, '60.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208160100', 'tradeTimeinMills': '1702069260000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 1), 'mat': 'US1Y'}, '75.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208160100', 'tradeTimeinMills': '1702069260000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 21, 1), 'mat': 'US1Y'}, '90.0m': {'open': '5.1360', 'high': '5.1390', 'low': '5.1360', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208152200', 'tradeTimeinMills': '1702066920000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 20, 22), 'mat': 'US1Y'}, '105.0m': {'open': '5.1360', 'high': '5.1360', 'low': '5.1360', 'close': '5.1360', 'volume': None, 'tradeTime': '20231208152000', 'tradeTimeinMills': '1702066800000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 20, 20), 'mat': 'US1Y'}, '120.0m': {'open': '5.1390', 'high': '5.1390', 'low': '5.1360', 'close': '5.1360', 'volume': None, 'tradeTime': '20231208150800', 'tradeTimeinMills': '1702066080000', '__typename': 'priceBarType', 'parsedTradeTime': datetime.datetime(2023, 12, 8, 20, 8), 'mat': 'US1Y'}, '135.0m': {'open': '5.1420', 'high': '5.1450', 'low': '5.1390', 'close': '5.1390', 'volume': None, 'tradeTime': '20231208145600', 'tradeTimeinMills': '1702065360000', '__typename': 'priceBarT ...
# Recent Spots Updated as of 2023-12-08 16:36:20.636896
# <style type="text/css">
# #T_0b2fa_row0_col1, #T_0b2fa_row1_col1, #T_0b2fa_row14_col8, #T_0b2fa_row20_col8 {
#   background-color: #ffadad;
#   color: #000000;
# }
# #T_0b2fa_row0_col2, #T_0b2fa_row1_col2, #T_0b2fa_row17_col1, #T_0b2fa_row21_col1, #T_0b2fa_row24_col5, #T_0b2fa_row24_col7, #T_0b2fa_row26_col1 {
#   background-color: #ff4848;
#   color: #f1f1f1;
# }
# #T_0b2fa_row0_col3 {
#   background-color: #7cbe7c;
#   color: #000000;
# }
# #T_0b2fa_row0_col4, #T_0b2fa_row1_col4, #T_0b2fa_row15_col5, #T_0b2fa_row17_col5, #T_0b2fa_row18_col7 {
#   background-color: #ff9595;
#   color: #000000;
# }
# #T_0b2fa_row0_col5, #T_0b2fa_row1_col5, #T_0b2fa_row3_col5, #T_0b2fa_row4_col5, #T_0b2fa_row6_col5, #T_0b2fa_row9_col5, #T_0b2fa_row13_col7, #T_0b2fa_row16_col7, #T_0b2fa_row29_col2, #T_0b2fa_row29_col3, #T_0b2fa_row29_col4, #T_0b2fa_row29_col5 {
#   background-color: #ffc1c1;
#   color: #000000;
# }
# #T_0b2fa_row0_col6 {
#   background-color: #f1f8f1;
#   color: #000000;
# }
# #T_0b2fa_row0_col7 {
#   background-color: #c9e4c9;
#   color: #000000;
# }
# #T_0b2fa_row0_col8, #T_0b2fa_row1_col8 {
#   background-color: #a1d0a1;
#   color: #000000;
# }
# #T_0b2fa_row1_col3, #T_0b2fa_row5_col3, #T_0b2fa_row8_col4, #T_0b2fa_row14_col4, #T_0b2fa_row30_col3 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_0b2fa_row1_col6, #T_0b2fa_row2_col6, #T_0b2fa_row3_col6, #T_0b2fa_row4_col6, #T_0b2fa_row6_col6, #T_0b2fa_row29_col6 {
#   background-color: #ffd9d9;
#   color: #000000;
# }
# #T_0b2fa_row1_col7, #T_0b2fa_row3_col7, #T_0b2fa_row12_col8, #T_0b2fa_row29_col7, #T_0b2fa_row29_col8 {
#   background-color: #fff5f5;
#   color: #000000;
# }
# #T_0b2fa_row2_col1, #T_0b2fa_row4_col4, #T_0b2fa_row5_col4, #T_0b2fa_row9_col4, #T_0b2fa_row11_col4, #T_0b2fa_row12_col1, #T_0b2fa_row13_col1, #T_0b2fa_row13_col5, #T_0b2fa_row18_col5, #T_0b2fa_row20_col4, #T_0b2fa_row22_col4, #T_0b2fa_row28_col1 {
#   background-color: #ff8585;
#   color: #f1f1f1;
# }
# #T_0b2fa_row2_col2, #T_0b2fa_row3_col2, #T_0b2fa_row8_col2, #T_0b2fa_row27_col2, #T_0b2fa_row27_col5, #T_0b2fa_row28_col7 {
#   background-color: #ff3030;
#   color: #f1f1f1;
# }
# #T_0b2fa_row2_col3, #T_0b2fa_row8_col3, #T_0b2fa_row14_col3, #T_0b2fa_row17_col3, #T_0b2fa_row18_col3, #T_0b2fa_row23_col4, #T_0b2fa_row28_col3, #T_0b2fa_row28_col5 {
#   background-color: #ff5050;
#   color: #f1f1f1;
# }
# #T_0b2fa_row2_col4, #T_0b2fa_row3_col4, #T_0b2fa_row6_col4, #T_0b2fa_row30_col1 {
#   background-color: #ff9191;
#   color: #000000;
# }
# #T_0b2fa_row2_col5, #T_0b2fa_row8_col6, #T_0b2fa_row15_col7, #T_0b2fa_row19_col5, #T_0b2fa_row22_col6 {
#   background-color: #ffb1b1;
#   color: #000000;
# }
# #T_0b2fa_row2_col7, #T_0b2fa_row5_col7, #T_0b2fa_row29_col1 {
#   background-color: #ffeded;
#   color: #000000;
# }
# #T_0b2fa_row2_col8, #T_0b2fa_row4_col8 {
#   background-color: #c5e2c5;
#   color: #000000;
# }
# #T_0b2fa_row3_col1, #T_0b2fa_row4_col1, #T_0b2fa_row5_col1, #T_0b2fa_row6_col1, #T_0b2fa_row7_col1, #T_0b2fa_row9_col1, #T_0b2fa_row10_col1, #T_0b2fa_row11_col1, #T_0b2fa_row14_col1, #T_0b2fa_row15_col1, #T_0b2fa_row16_col1, #T_0b2fa_row30_col8 {
#   background-color: #ff7070;
#   color: #f1f1f1;
# }
# #T_0b2fa_row3_col3, #T_0b2fa_row4_col3, #T_0b2fa_row10_col3, #T_0b2fa_row11_col3, #T_0b2fa_row12_col3, #T_0b2fa_row13_col3, #T_0b2fa_row15_col3, #T_0b2fa_row16_col2, #T_0b2fa_row19_col2, #T_0b2fa_row21_col2, #T_0b2fa_row22_col3 {
#   background-color: #ff6060;
#   color: #f1f1f1;
# }
# #T_0b2fa_row3_col8, #T_0b2fa_row6_col8 {
#   background-color: #d5ead5;
#   color: #000000;
# }
# #T_0b2fa_row4_col2, #T_0b2fa_row5_col2, #T_0b2fa_row10_col2, #T_0b2fa_row11_col2, #T_0b2fa_row17_col2, #T_0b2fa_row18_col2, #T_0b2fa_row22_col1, #T_0b2fa_row23_col1, #T_0b2fa_row26_col2, #T_0b2fa_row27_col4 {
#   background-color: #ff3838;
#   color: #f1f1f1;
# }
# #T_0b2fa_row4_col7, #T_0b2fa_row10_col8 {
#   background-color: #fdfefd;
#   color: #000000;
# }
# #T_0b2fa_row5_col5, #T_0b2fa_row7_col5, #T_0b2fa_row10_col6, #T_0b2fa_row11_col6, #T_0b2fa_row12_col6, #T_0b2fa_row15_col8, #T_0b2fa_row16_col5, #T_0b2fa_row19_col6, #T_0b2fa_row19_col8, #T_0b2fa_row21_col5, #T_0b2fa_row21_col6 {
#   background-color: #ffbdbd;
#   color: #000000;
# }
# #T_0b2fa_row5_col6, #T_0b2fa_row7_col7, #T_0b2fa_row9_col6, #T_0b2fa_row10_col7, #T_0b2fa_row12_col7, #T_0b2fa_row21_col7, #T_0b2fa_row22_col8 {
#   background-color: #ffd5d5;
#   color: #000000;
# }
# #T_0b2fa_row5_col8 {
#   background-color: #ddeedd;
#   color: #000000;
# }
# #T_0b2fa_row6_col2, #T_0b2fa_row7_col2, #T_0b2fa_row9_col2, #T_0b2fa_row12_col2, #T_0b2fa_row14_col2, #T_0b2fa_row22_col2, #T_0b2fa_row28_col8 {
#   background-color: #ff4444;
#   color: #f1f1f1;
# }
# #T_0b2fa_row6_col3, #T_0b2fa_row7_col3, #T_0b2fa_row9_col3, #T_0b2fa_row14_col5, #T_0b2fa_row16_col3, #T_0b2fa_row20_col3, #T_0b2fa_row21_col3, #T_0b2fa_row23_col7, #T_0b2fa_row30_col6 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_0b2fa_row6_col7, #T_0b2fa_row8_col8, #T_0b2fa_row9_col7, #T_0b2fa_row11_col8 {
#   background-color: #fffdfd;
#   color: #000000;
# }
# #T_0b2fa_row7_col4, #T_0b2fa_row12_col4, #T_0b2fa_row15_col4, #T_0b2fa_row23_col8, #T_0b2fa_row30_col2 {
#   background-color: #ff8181;
#   color: #f1f1f1;
# }
# #T_0b2fa_row7_col6, #T_0b2fa_row8_col7, #T_0b2fa_row16_col6, #T_0b2fa_row22_col7 {
#   background-color: #ffc9c9;
#   color: #000000;
# }
# #T_0b2fa_row7_col8 {
#   background-color: #f5faf5;
#   color: #000000;
# }
# #T_0b2fa_row8_col1, #T_0b2fa_row18_col1, #T_0b2fa_row19_col1, #T_0b2fa_row20_col1, #T_0b2fa_row27_col1, #T_0b2fa_row28_col4 {
#   background-color: #ff5c5c;
#   color: #f1f1f1;
# }
# #T_0b2fa_row8_col5, #T_0b2fa_row10_col5, #T_0b2fa_row11_col5, #T_0b2fa_row12_col5, #T_0b2fa_row13_col6, #T_0b2fa_row15_col6, #T_0b2fa_row19_col4 {
#   background-color: #ffa5a5;
#   color: #000000;
# }
# #T_0b2fa_row9_col8 {
#   background-color: #cde6cd;
#   color: #000000;
# }
# #T_0b2fa_row10_col4, #T_0b2fa_row13_col4, #T_0b2fa_row17_col4, #T_0b2fa_row18_col4, #T_0b2fa_row30_col4 {
#   background-color: #ff7878;
#   color: #f1f1f1;
# }
# #T_0b2fa_row11_col7, #T_0b2fa_row21_col8 {
#   background-color: #ffdddd;
#   color: #000000;
# }
# #T_0b2fa_row13_col2, #T_0b2fa_row15_col2, #T_0b2fa_row28_col2, #T_0b2fa_row28_col6 {
#   background-color: #ff4c4c;
#   color: #f1f1f1;
# }
# #T_0b2fa_row13_col8, #T_0b2fa_row16_col8 {
#   background-color: #ffc5c5;
#   color: #000000;
# }
# #T_0b2fa_row14_col6, #T_0b2fa_row19_col3 {
#   background-color: #ff8d8d;
#   color: #000000;
# }
# #T_0b2fa_row14_col7, #T_0b2fa_row17_col6, #T_0b2fa_row18_col6, #T_0b2fa_row18_col8, #T_0b2fa_row20_col5, #T_0b2fa_row20_col6, #T_0b2fa_row22_col5 {
#   background-color: #ff9999;
#   color: #000000;
# }
# #T_0b2fa_row16_col4, #T_0b2fa_row21_col4 {
#   background-color: #ff9d9d;
#   color: #000000;
# }
# #T_0b2fa_row17_col7 {
#   background-color: #ffa1a1;
#   color: #000000;
# }
# #T_0b2fa_row17_col8, #T_0b2fa_row20_col7 {
#   background-color: #ffa9a9;
#   color: #000000;
# }
# #T_0b2fa_row19_col7 {
#   background-color: #ffcdcd;
#   color: #000000;
# }
# #T_0b2fa_row20_col2, #T_0b2fa_row24_col8 {
#   background-color: #ff5454;
#   color: #f1f1f1;
# }
# #T_0b2fa_row23_col2 {
#   background-color: #ff2020;
#   color: #f1f1f1;
# }
# #T_0b2fa_row23_col3 {
#   background-color: #ff3434;
#   color: #f1f1f1;
# }
# #T_0b2fa_row23_col5, #T_0b2fa_row23_col6, #T_0b2fa_row30_col7 {
#   background-color: #ff6464;
#   color: #f1f1f1;
# }
# #T_0b2fa_row24_col1, #T_0b2fa_row26_col4 {
#   background-color: #ff2424;
#   color: #f1f1f1;
# }
# #T_0b2fa_row24_col2, #T_0b2fa_row24_col3, #T_0b2fa_row26_col3, #T_0b2fa_row27_col3 {
#   background-color: #ff2828;
#   color: #f1f1f1;
# }
# #T_0b2fa_row24_col4, #T_0b2fa_row27_col6 {
#   background-color: #ff3c3c;
#   color: #f1f1f1;
# }
# #T_0b2fa_row24_col6 {
#   background-color: #ff4040;
#   color: #f1f1f1;
# }
# #T_0b2fa_row25_col1, #T_0b2fa_row25_col2, #T_0b2fa_row25_col3, #T_0b2fa_row25_col4, #T_0b2fa_row25_col5, #T_0b2fa_row25_col6, #T_0b2fa_row26_col7, #T_0b2fa_row26_col8 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_0b2fa_row25_col7, #T_0b2fa_row25_col8, #T_0b2fa_row27_col7 {
#   background-color: #ff0c0c;
#   color: #f1f1f1;
# }
# #T_0b2fa_row26_col5 {
#   background-color: #ff1414;
#   color: #f1f1f1;
# }
# #T_0b2fa_row26_col6 {
#   background-color: #ff1818;
#   color: #f1f1f1;
# }
# #T_0b2fa_row27_col8 {
#   background-color

# %%
plot_current_yields(current_yields_dict)
plot_current_yields_and_historicals(
    current_yields_dict=current_yields_dict,
    df_historical_par_yields=df_historical_par_yields,
    df_recent_spots=df_recent_spots,
    plot_yesterday=True,
    plot_week=True,
    # plot_month=True,
    # plot_year=True,
    # plot_five_min=True,
    # plot_ten_min=True,
    # plot_thirty_min=True,
    # plot_sixty_min=True,
    plot_120_min=True,
)

# %%
category_colors = {
    "Inverted": "red",
    "Slight Inverted": "darkorange",
    "Flat": "goldenrod",
    "Slight Normal": "lightgreen",
    "Normal": "green",
    "Unknown": "grey"  
}

def apply_color(val):
    color = category_colors.get(val, "white")  
    return f'background-color: {color}'

df_yield_corr = yields_corr(current_yields_dict=current_yields_dict, df_historical_par_yields=df_historical_par_yields, show_recents_days=True, num_of_months=36)
styled_df_yield_corr = df_yield_corr.style.background_gradient(cmap=LinearSegmentedColormap.from_list('rg', ["r", "w", "g"], N=256), subset=[col for col in df_yield_corr.columns if col not in ['Category', 'Date']])
styled_df_yield_corr = styled_df_yield_corr.applymap(apply_color, subset=['Category'])
styled_df_yield_corr
# Out:
# Date: 2023-01-02 00:00:00 probably not found:  list index out of range  trying next day
# <style type="text/css">
# #T_7401c_row0_col1, #T_7401c_row6_col3, #T_7401c_row7_col3, #T_7401c_row21_col9 {
#   background-color: #209020;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col2, #T_7401c_row1_col1, #T_7401c_row2_col1, #T_7401c_row12_col1 {
#   background-color: #289328;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col3, #T_7401c_row3_col7 {
#   background-color: #2c962c;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col4, #T_7401c_row2_col2, #T_7401c_row7_col4 {
#   background-color: #389c38;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col5, #T_7401c_row1_col3, #T_7401c_row2_col3, #T_7401c_row6_col5 {
#   background-color: #3c9e3c;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col6, #T_7401c_row1_col5, #T_7401c_row12_col5 {
#   background-color: #4aa44a;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col7, #T_7401c_row8_col5, #T_7401c_row14_col4 {
#   background-color: #5cae5c;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col8, #T_7401c_row17_col2 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col9 {
#   background-color: #ff3a3a;
#   color: #f1f1f1;
# }
# #T_7401c_row0_col10, #T_7401c_row6_col10, #T_7401c_row7_col10, #T_7401c_row8_col10, #T_7401c_row12_col10, #T_7401c_row13_col10, #T_7401c_row14_col10, #T_7401c_row15_col10, #T_7401c_row16_col10 {
#   background-color: red;
# }
# #T_7401c_row1_col2 {
#   background-color: #369b36;
#   color: #f1f1f1;
# }
# #T_7401c_row1_col4, #T_7401c_row14_col1, #T_7401c_row14_col2, #T_7401c_row16_col5 {
#   background-color: #48a348;
#   color: #f1f1f1;
# }
# #T_7401c_row1_col6 {
#   background-color: #56ab56;
#   color: #f1f1f1;
# }
# #T_7401c_row1_col7, #T_7401c_row12_col6, #T_7401c_row13_col2 {
#   background-color: #68b368;
#   color: #f1f1f1;
# }
# #T_7401c_row1_col8, #T_7401c_row16_col7 {
#   background-color: #70b870;
#   color: #f1f1f1;
# }
# #T_7401c_row1_col9, #T_7401c_row5_col9, #T_7401c_row24_col7, #T_7401c_row25_col7, #T_7401c_row35_col5 {
#   background-color: #ff4e4e;
#   color: #f1f1f1;
# }
# #T_7401c_row1_col10, #T_7401c_row2_col10, #T_7401c_row3_col10, #T_7401c_row5_col10, #T_7401c_row9_col10, #T_7401c_row10_col10, #T_7401c_row11_col10, #T_7401c_row17_col10 {
#   background-color: darkorange;
# }
# #T_7401c_row2_col4, #T_7401c_row2_col5, #T_7401c_row16_col1 {
#   background-color: #44a244;
#   color: #f1f1f1;
# }
# #T_7401c_row2_col6, #T_7401c_row7_col5, #T_7401c_row13_col1, #T_7401c_row14_col3, #T_7401c_row15_col1 {
#   background-color: #4ca64c;
#   color: #f1f1f1;
# }
# #T_7401c_row2_col7, #T_7401c_row9_col2 {
#   background-color: #50a850;
#   color: #f1f1f1;
# }
# #T_7401c_row2_col8, #T_7401c_row15_col2 {
#   background-color: #58ac58;
#   color: #f1f1f1;
# }
# #T_7401c_row2_col9 {
#   background-color: #ff7e7e;
#   color: #f1f1f1;
# }
# #T_7401c_row3_col1 {
#   background-color: #0e860e;
#   color: #f1f1f1;
# }
# #T_7401c_row3_col2, #T_7401c_row5_col7, #T_7401c_row8_col2 {
#   background-color: #128812;
#   color: #f1f1f1;
# }
# #T_7401c_row3_col3, #T_7401c_row3_col4, #T_7401c_row5_col8, #T_7401c_row6_col2 {
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_7401c_row3_col5 {
#   background-color: #1a8c1a;
#   color: #f1f1f1;
# }
# #T_7401c_row3_col6 {
#   background-color: #269226;
#   color: #f1f1f1;
# }
# #T_7401c_row3_col8, #T_7401c_row6_col4, #T_7401c_row22_col9 {
#   background-color: #329832;
#   color: #f1f1f1;
# }
# #T_7401c_row3_col9, #T_7401c_row28_col5 {
#   background-color: #ff5858;
#   color: #f1f1f1;
# }
# #T_7401c_row4_col1, #T_7401c_row5_col6, #T_7401c_row7_col1 {
#   background-color: #0a840a;
#   color: #f1f1f1;
# }
# #T_7401c_row4_col2 {
#   background-color: #108810;
#   color: #f1f1f1;
# }
# #T_7401c_row4_col3, #T_7401c_row6_col1 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_7401c_row4_col4, #T_7401c_row8_col1, #T_7401c_row25_col9 {
#   background-color: #048204;
#   color: #f1f1f1;
# }
# #T_7401c_row4_col5, #T_7401c_row4_col6, #T_7401c_row4_col7, #T_7401c_row4_col8, #T_7401c_row5_col1, #T_7401c_row5_col2, #T_7401c_row5_col3, #T_7401c_row5_col4, #T_7401c_row28_col9, #T_7401c_row29_col9, #T_7401c_row30_col9, #T_7401c_row31_col9, #T_7401c_row32_col9, #T_7401c_row33_col9, #T_7401c_row34_col9, #T_7401c_row35_col9 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_7401c_row4_col9 {
#   background-color: #ffbaba;
#   color: #000000;
# }
# #T_7401c_row4_col10, #T_7401c_row18_col10, #T_7401c_row19_col10 {
#   background-color: goldenrod;
# }
# #T_7401c_row5_col5, #T_7401c_row26_col9, #T_7401c_row27_col9, #T_7401c_row36_col9 {
#   background-color: #028002;
#   color: #f1f1f1;
# }
# #T_7401c_row6_col6, #T_7401c_row11_col1, #T_7401c_row17_col3 {
#   background-color: #52a852;
#   color: #f1f1f1;
# }
# #T_7401c_row6_col7 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_7401c_row6_col8 {
#   background-color: #6ab46a;
#   color: #f1f1f1;
# }
# #T_7401c_row6_col9, #T_7401c_row30_col5 {
#   background-color: #ff2828;
#   color: #f1f1f1;
# }
# #T_7401c_row7_col2 {
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_7401c_row7_col6, #T_7401c_row10_col2 {
#   background-color: #64b264;
#   color: #f1f1f1;
# }
# #T_7401c_row7_col7, #T_7401c_row13_col3, #T_7401c_row15_col4, #T_7401c_row17_col5 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_7401c_row7_col8, #T_7401c_row14_col6 {
#   background-color: #88c388;
#   color: #000000;
# }
# #T_7401c_row7_col9 {
#   background-color: #ff1414;
#   color: #f1f1f1;
# }
# #T_7401c_row8_col3, #T_7401c_row9_col1 {
#   background-color: #229022;
#   color: #f1f1f1;
# }
# #T_7401c_row8_col4 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_7401c_row8_col6 {
#   background-color: #7ebe7e;
#   color: #000000;
# }
# #T_7401c_row8_col7 {
#   background-color: #9acc9a;
#   color: #000000;
# }
# #T_7401c_row8_col8, #T_7401c_row10_col7 {
#   background-color: #aed6ae;
#   color: #000000;
# }
# #T_7401c_row8_col9, #T_7401c_row31_col2, #T_7401c_row35_col2 {
#   background-color: #ff0606;
#   color: #f1f1f1;
# }
# #T_7401c_row9_col3, #T_7401c_row15_col3, #T_7401c_row16_col6, #T_7401c_row17_col4 {
#   background-color: #60b060;
#   color: #f1f1f1;
# }
# #T_7401c_row9_col4 {
#   background-color: #78bc78;
#   color: #000000;
# }
# #T_7401c_row9_col5, #T_7401c_row17_col1 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_7401c_row9_col6 {
#   background-color: #a0d0a0;
#   color: #000000;
# }
# #T_7401c_row9_col7, #T_7401c_row13_col5 {
#   background-color: #a8d3a8;
#   color: #000000;
# }
# #T_7401c_row9_col8, #T_7401c_row10_col8, #T_7401c_row18_col5 {
#   background-color: #b2d8b2;
#   color: #000000;
# }
# #T_7401c_row9_col9 {
#   background-color: #ff3e3e;
#   color: #f1f1f1;
# }
# #T_7401c_row10_col1, #T_7401c_row16_col2, #T_7401c_row20_col9 {
#   background-color: #3a9c3a;
#   color: #f1f1f1;
# }
# #T_7401c_row10_col3, #T_7401c_row14_col5 {
#   background-color: #6eb66e;
#   color: #f1f1f1;
# }
# #T_7401c_row10_col4 {
#   background-color: #80c080;
#   color: #000000;
# }
# #T_7401c_row10_col5, #T_7401c_row15_col5, #T_7401c_row18_col3 {
#   background-color: #90c890;
#   color: #000000;
# }
# #T_7401c_row10_col6, #T_7401c_row18_col2 {
#   background-color: #a4d2a4;
#   color: #000000;
# }
# #T_7401c_row10_col9, #T_7401c_row33_col7, #T_7401c_row35_col6 {
#   background-color: #ff5252;
#   color: #f1f1f1;
# }
# #T_7401c_row11_col2 {
#   background-color: #74ba74;
#   color: #f1f1f1;
# }
# #T_7401c_row11_col3, #T_7401c_row23_col9 {
#   background-color: #7cbe7c;
#   color: #000000;
# }
# #T_7401c_row11_col4 {
#   background-color: #8ec68e;
#   color: #000000;
# }
# #T_7401c_row11_col5 {
#   background-color: #a2d0a2;
#   color: #000000;
# }
# #T_7401c_row11_col6, #T_7401c_row18_col1 {
#   background-color: #badcba;
#   color: #000000;
# }
# #T_7401c_row11_col7 {
#   background-color: #c6e2c6;
#   color: #000000;
# }
# #T_7401c_row11_col8, #T_7401c_row15_col8, #T_7401c_row18_col6, #T_7401c_row21_col4, #T_7401c_row22_col3 {
#   background-color: #d2e8d2;
#   color: #000000;
# }
# #T_7401c_row11_col9, #T_7401c_row27_col3, #T_7401c_row33_col6, #T_7401c_row36_col8 {
#   background-color: #ff4848;
#   color: #f1f1f1;
# }
# #T_7401c_row12_col2 {
#   background-color: #168b16;
#   color: #f1f1f1;
# }
# #T_7401c_row12_col3 {
#   background-color: #1c8e1c;
#   color: #f1f1f1;
# }
# #T_7401c_row12_col4, #T_7401c_row16_col4 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_7401c_row12_col7 {
#   background-color: #8cc68c;
#   color: #000000;
# }
# #T_7401c_row12_col8, #T_7401c_row18_col4 {
#   background-color: #9ece9e;
#   color: #000000;
# }
# #T_7401c_row12_col9, #T_7401c_

# %%
def cnbc_us_treasury_yields_fetcher(mat: str) -> List[Dict[str, str | int]]:
    res = requests.get(
        f"https://webql-redesign.cnbcfm.com/graphql?operationName=getQuoteChartData&variables=%7B%22symbol%22%3A%22{mat}%22%2C%22timeRange%22%3A%221D%22%7D&extensions=%7B%22persistedQuery%22%3A%7B%22version%22%3A1%2C%22sha256Hash%22%3A%2261b6376df0a948ce77f977c69531a4a8ed6788c5ebcdd5edd29dd878ce879c8d%22%7D%7D"
    )
    return res.json()["data"]["chartData"]["priceBars"]

# %%
mats = ["US1Y", "US2Y", "US3Y", "US5Y", "US7Y", "US10Y", "US20Y", "US30Y"]
daily_yields_dict = {mat: cnbc_us_treasury_yields_fetcher(mat) for mat in mats}
[yields_candlestick_plot(data, use_candlestick=True, use_today=True, mat_label=mat) for mat, data in daily_yields_dict.items()]
# Out:
# [None, None, None, None, None, None, None, None]

# %%
def plot_spreads(mat1: str, mat2: str, daily_yields_dict: Dict[str, List[Dict[str, str | int]]]):
    chainmap_mat1 = {item["tradeTimeinMills"]:item for item in daily_yields_dict[mat1]}
    chainmap_mat2 = {item["tradeTimeinMills"]:item for item in daily_yields_dict[mat2]}

    def calc_spread(dict1, dict2, key):
        def format_float(item):
            return float(str((item)).strip("%")) 
        
        if key in dict1 and key in dict2:
            return {
                'open': format_float(dict1[key]['open']) - format_float(dict2[key]['open']),
                'high': format_float(dict1[key]['high']) - format_float(dict2[key]['high']),
                'low': format_float(dict1[key]['low']) - format_float(dict2[key]['low']),
                'close': format_float(dict1[key]['close']) - format_float(dict2[key]['close']),
                'tradeTimeinMills': key,
            }
        
        return None

    spread_dict = calc_daily_spreads(current_yields_dict, mat2, mat1)
    spread_df = pd.DataFrame([spread_dict])
    spread_df = spread_df.set_index('spread_title')
    display(spread_df.T)
        
    twos_tens_chainmap = [calc_spread(chainmap_mat2, chainmap_mat1, key) for key in chainmap_mat1.keys()]
    twos_tens_chainmap = list(filter(lambda item: item is not None, twos_tens_chainmap))
    yields_candlestick_plot(twos_tens_chainmap, use_candlestick=False, use_today=False, mat_label=f"{mat1}s{mat2}s", just_close_plot=True)

# %%
plot_spreads("US2Y", "US10Y", daily_yields_dict)
plot_spreads("US5Y", "US30Y", daily_yields_dict)
# Out:
# spread_title  US10Y - US2Y (basis points)
# last_spread                         -49.0
# open_spread                         -44.0
# high_spread                         -46.2
# low_spread                          -44.6
# spread_title  US30Y - US5Y (basis points)
# last_spread                           6.7
# open_spread                          12.7
# high_spread                           7.3
# low_spread                           11.8
